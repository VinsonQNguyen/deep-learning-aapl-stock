# %% [markdown]
# # Predicting Apple (AAPL) Stock Trends with LSTM: 10-Year Historical Analysis

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
# Out:
# /Users/vinsonnguyen/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# We are gonna use the Python's yfinance library to get historic price data for NVIDIA **(NVDA)**. We are gonna be looking at the past 4 years.

# %%
news_data = yf.download(
    tickers = 'AAPL',
    start = '2015-01-01',
    end = '2025-01-01',
    interval = '1d',
    auto_adjust = True
).dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
news_data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2015-01-02   24.261040   24.729263   23.821664   24.718167  212818400
# 2015-01-05   23.577579   24.110156   23.391179   24.030269  257142000
# 2015-01-06   23.579786   23.839417   23.218078   23.641920  263188400
# 2015-01-07   23.910429   24.010286   23.677426   23.788380  160423600
# 2015-01-08   24.829128   24.886824   24.121246   24.238858  237458000
# ...                ...         ...         ...         ...        ...
# 2024-12-24  257.286682  257.296626  254.386957  254.586262   23234700
# 2024-12-26  258.103729  259.179926  256.718662  257.276679   27237100
# 2024-12-27  254.685883  257.784897  252.164833  256.917949   42355300
# 2024-12-30  251.307877  252.603281  249.863009  251.337769   35557500
# 2024-12-31  249.534180  252.384064  248.547676  251.547039   39480700
#
# [2516 rows x 5 columns]

# %% [markdown]
# We are gonna plot two separate graphs
#
# ### High and Low Prices
# - Good for volatility/intraday risk

# %%
dates = news_data.index.date
high_prices = news_data['High']
low_prices = news_data['Low']

# %%
plt.figure(figsize = (18, 8)) 
plt.plot(dates, high_prices, label = 'High')
plt.plot(dates, low_prices, label = 'Low')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval = 4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.title('High vs. Low Prices (NVDA, 4 Years)')
plt.xlabel('Dates/Time')
plt.ylabel('Prices ($USD)')
plt.legend(fontsize = 16)

plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### Closing and Opening Prices
# - Good for overnight sentiment

# %%
dates = news_data.index.date
closing_prices = news_data['Close']
opening_prices = news_data['Open']

# %%
plt.figure(figsize = (18, 8)) 
plt.plot(dates, closing_prices, label = 'Close')
plt.plot(dates, opening_prices, label = 'Open')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval = 4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.title('Closing vs. Opening Prices (NVDA, 4 Years)')
plt.xlabel('Dates/Time')
plt.ylabel('Prices ($USD)')
plt.legend(fontsize = 16)

plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## Model for Predicting Closing Prices

# %% [markdown]
# - We will be using a training/test split of .80/.20

# %%
close_data = news_data[['Close']].values

training_amount = .8
training_index  = int(np.ceil(len(close_data) * training_amount))

window = 90

close_training_data = close_data[0:training_index]
close_test_data = close_data[training_index-window:]

# %% [markdown]
# - We are gonna scale the data now using sklearn's **MinMaxScaler()**
# - Only gonna transform on test or else the model would use knowledge of the test distribution too (prevent data leakage)

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))
training_scaled = scaler.fit_transform(close_training_data.reshape(-1, 1))
testing_scaled = scaler.transform(close_test_data.reshape(-1, 1))

# %% [markdown]
# - We will be using a sequence length/window of 90 days
# - Below is a function **make_data(X, window)** defined to help create our training/test sets

# %%
def make_data(X, window):
    X_output, y_output = [], []
    for i in range(window, len(X)):
        X_output.append(X[i - window:i])
        y_output.append(X[i])
    return np.array(X_output), np.array(y_output)

# %%
X_train, y_train = make_data(training_scaled, window)
X_test, y_test = make_data(testing_scaled, window)

# %%
X_train = torch.tensor(X_train).float()
X_test = torch.tensor(X_test).float()
y_train = torch.tensor(y_train).float()
y_test = torch.tensor(y_test).float()

# %%
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

batch_size = 64

train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle = False)

# %%
# to get this run to on gpu
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([64, 90, 1]) torch.Size([64, 1])

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers
        self.LSTM = nn.LSTM(input_size, hidden_size, num_stacked_layers, batch_first = True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)

        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.LSTM(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# LSTM(input, hidden size, number of stacked layers
# we will use a hidden size of 64
# we will use 2 stacked layers)

model = LSTM(1, 64, 2)
model.to(device)
model
# Out:
# LSTM(
#   (LSTM): LSTM(1, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
# we will use a learning rate of .001
# we will be using MSE as a loss function and evaluating with RMSE after

# %%
learning_rate = .001
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# remember we made our batch_size = 64

batch_size = 64

# %%
def train_epoch():
    model.train()
    print(f'Epoch: {1 + epoch}')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print()
    
def validate_epoch():
    model.eval() 
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()
            
    average_loss_across_batches = running_loss / len(test_loader)
    
    print(f'Validation Loss: {average_loss_across_batches}')
    print('-------------------------------------')
    print()

# %%
num_epochs = 50
for epoch in range(num_epochs):
    train_epoch()
    validate_epoch()
# Out:
# Epoch: 1
#
# Validation Loss: 0.4914883077144623
# -------------------------------------
#
# Epoch: 2
#
# Validation Loss: 0.16641884413547814
# -------------------------------------
#
# Epoch: 3
#
# Validation Loss: 0.11335381685057655
# -------------------------------------
#
# Epoch: 4
#
# Validation Loss: 0.09554099070373923
# -------------------------------------
#
# Epoch: 5
#
# Validation Loss: 0.06029769580345601
# -------------------------------------
#
# Epoch: 6
#
# Validation Loss: 0.04698143561836332
# -------------------------------------
#
# Epoch: 7
#
# Validation Loss: 0.03747526655206457
# -------------------------------------
#
# Epoch: 8
#
# Validation Loss: 0.026762427994981408
# -------------------------------------
#
# Epoch: 9
#
# Validation Loss: 0.04060514469165355
# -------------------------------------
#
# Epoch: 10
#
# Validation Loss: 0.041554281022399664
# -------------------------------------
#
# Epoch: 11
#
# Validation Loss: 0.023281312664039433
# -------------------------------------
#
# Epoch: 12
#
# Validation Loss: 0.023879579501226544
# -------------------------------------
#
# Epoch: 13
#
# Validation Loss: 0.03152732679154724
# -------------------------------------
#
# Epoch: 14
#
# Validation Loss: 0.017081237281672657
# -------------------------------------
#
# Epoch: 15
#
# Validation Loss: 0.01391885569319129
# -------------------------------------
#
# Epoch: 16
#
# Validation Loss: 0.007874611372244544
# -------------------------------------
#
# Epoch: 17
#
# Validation Loss: 0.005166607807041146
# -------------------------------------
#
# Epoch: 18
#
# Validation Loss: 0.01285910265869461
# -------------------------------------
#
# Epoch: 19
#
# Validation Loss: 0.009501606895355508
# -------------------------------------
#
# Epoch: 20
#
# Validation Loss: 0.005077856301795691
# -------------------------------------
#
# Epoch: 21
#
# Validation Loss: 0.004144667698710691
# -------------------------------------
#
# Epoch: 22
#
# Validation Loss: 0.011291319271549582
# -------------------------------------
#
# Epoch: 23
#
# Validation Loss: 0.010371186304837465
# -------------------------------------
#
# Epoch: 24
#
# Validation Loss: 0.019466007419396192
# -------------------------------------
#
# Epoch: 25
#
# Validation Loss: 0.009335504175396636
# -------------------------------------
#
# Epoch: 26
#
# Validation Loss: 0.00534967913699802
# -------------------------------------
#
# Epoch: 27
#
# Validation Loss: 0.006624793881201185
# -------------------------------------
#
# Epoch: 28
#
# Validation Loss: 0.0058483692846493796
# -------------------------------------
#
# Epoch: 29
#
# Validation Loss: 0.0038176167145138606
# -------------------------------------
#
# Epoch: 30
#
# Validation Loss: 0.009694622014649212
# -------------------------------------
#
# Epoch: 31
#
# Validation Loss: 0.011053452064516023
# -------------------------------------
#
# Epoch: 32
#
# Validation Loss: 0.006229976279428229
# -------------------------------------
#
# Epoch: 33
#
# Validation Loss: 0.0060201605228940025
# -------------------------------------
#
# Epoch: 34
#
# Validation Loss: 0.0054501765698660165
# -------------------------------------
#
# Epoch: 35
#
# Validation Loss: 0.004507400080910884
# -------------------------------------
#
# Epoch: 36
#
# Validation Loss: 0.013324070518137887
# -------------------------------------
#
# Epoch: 37
#
# Validation Loss: 0.003107197175268084
# -------------------------------------
#
# Epoch: 38
#
# Validation Loss: 0.011340699827997014
# -------------------------------------
#
# Epoch: 39
#
# Validation Loss: 0.006737620205967687
# -------------------------------------
#
# Epoch: 40
#
# Validation Loss: 0.002990821514686104
# -------------------------------------
#
# Epoch: 41
#
# Validation Loss: 0.002983167963975575
# -------------------------------------
#
# Epoch: 42
#
# Validation Loss: 0.003255319388699718
# -------------------------------------
#
# Epoch: 43
#
# Validation Loss: 0.004344756147474982
# -------------------------------------
#
# Epoch: 44
#
# Validation Loss: 0.002615310120745562
# -------------------------------------
#
# Epoch: 45
#
# Validation Loss: 0.015239189844578505
# -------------------------------------
#
# Epoch: 46
#
# Validation Loss: 0.0027797239963547327
# -------------------------------------
#
# Epoch: 47
#
# Validation Loss: 0.004409582688822411
# -------------------------------------
#
# Epoch: 48
#
# Validation Loss: 0.002984830047353171
# -------------------------------------
#
# Epoch: 49
#
# Validation Loss: 0.007977601257152855
# -------------------------------------
#
# Epoch: 50
#
# Validation Loss: 0.0024213619471993297
# -------------------------------------

# %%
y_test, close_test_data
# Out:
# (tensor([[0.3623],
#          [0.3016],
#          [0.3177],
#          [0.3009],
#          [0.3584],
#          [0.3651],
#          [0.3723],
#          [0.4068],
#          [0.4058],
#          [0.4227],
#          [0.4374],
#          [0.4283],
#          [0.4290],
#          [0.4615],
#          [0.5020],
#          [0.5198],
#          [0.5114],
#          [0.5376],
#          [0.5623],
#          [0.5256],
#          [0.5418],
#          [0.5560],
#          [0.6234],
#          [0.6693],
#          [0.6347],
#          [0.6712],
#          [0.6371],
#          [0.6240],
#          [0.6286],
#          [0.6642],
#          [0.6560],
#          [0.6827],
#          [0.6624],
#          [0.6479],
#          [0.5969],
#          [0.6023],
#          [0.6085],
#          [0.5748],
#          [0.5899],
#          [0.5836],
#          [0.5573],
#          [0.5648],
#          [0.6289],
#          [0.6639],
#          [0.6360],
#          [0.6519],
#          [0.6234],
#          [0.5972],
#          [0.6219],
#          [0.6484],
#          [0.6534],
#          [0.6892],
#          [0.6786],
#          [0.7086],
#          [0.7321],
#          [0.7140],
#          [0.7277],
#          [0.7443],
#          [0.7196],
#          [0.7117],
#          [0.7508],
#          [0.7707],
#          [0.8025],
#          [0.8184],
#          [0.8116],
#          [0.7882],
#          [0.7995],
#          [0.7665],
#          [0.7511],
#          [0.7424],
#          [0.8107],
#          [0.8063],
#          [0.8066],
#          [0.8221],
#          [0.8366],
#          [0.8244],
#          [0.8040],
#          [0.8078],
#          [0.7883],
#          [0.7882],
#          [0.8464],
#          [0.8623],
#          [0.8612],
#          [0.8480],
#          [0.8344],
#          [0.8136],
#          [0.9110],
#          [0.9101],
#          [0.8884],
#          [0.9108],
#          [0.9132],
#          [0.9014],
#          [0.8952],
#          [0.8952],
#          [0.9029],
#          [0.9325],
#          [0.9339],
#          [0.9219],
#          [0.8888],
#          [0.8923],
#          [0.9067],
#          [0.9373],
#          [0.9607],
#          [0.9601],
#          [0.9957],
#          [1.0065],
#          [0.9893],
#          [0.9847],
#          [0.9672],
#          [1.0017],
#          [1.0066],
#          [1.0421],
#          [1.0360],
#          [1.0441],
#          [1.0699],
#          [1.0562],
#          [1.0573],
#          [1.0442],
#          [1.0823],
#          [1.0783],
#          [1.0606],
#          [1.0956],
#          [1.1105],
#          [1.1147],
#          [1.1696],
#          [1.1507],
#          [1.1366],
#          [1.1426],
#          [1.1284],
#          [1.1025],
#          [1.0958],
#          [1.1170],
#          [1.1267],
#          [1.1285],
#          [1.1699],
#          [1.1666],
#          [1.1838],
#          [1.1591],
#          [1.1442],
#          [1.1544],
#          [1.1653],
#          [1.1763],
#          [1.1602],
#          [1.1930],
#          [1.2007],
#          [1.1902],
#          [1.1522],
#          [1.1345],
#          [1.0195],
#          [0.9801],
#          [0.9921],
#          [0.9719],
#          [0.9691],
#          [0.9699],
#          [0.9908],
#          [0.9656],
#          [0.9546],
#          [0.9223],
#          [0.9285],
#          [0.9454],
#          [0.9628],
#          [1.0117],
#          [0.9522],
#          [0.9802],
#          [1.0000],
#          [1.0493],
#          [1.0936],
#          [1.0964],
#          [1.1163],
#          [1.1193],
#          [1.0341],
#          [0.9670],
#          [0.9748],
#          [0.9896],
#          [0.9512],
#          [0.9249],
#          [0.9441],
#          [0.9350],
#          [0.9721],
#          [0.9859],
#          [0.9410],
#          [0.9214],
#          [0.9322],
#          [0.9484],
#          [0.8967],
#          [0.8775],
#          [0.8808],
#          [0.8873],
#          [0.9192],
#          [0.9022],
#          [0.9180],
#          [0.9337],
#          [0.9661],
#          [0.9849],
#          [0.9774],
#          [0.9951],
#          [1.0065],
#          [0.9832],
#          [0.9815],
#          [0.9618],
#          [0.9454],
#          [0.9406],
#          [0.9082],
#          [0.9098],
#          [0.9153],
#          [0.8859],
#          [0.8331],
#          [0.8498],
#          [0.8757],
#          [0.8818],
#          [0.9219],
#          [0.9671],
#          [0.9556],
#          [0.9879],
#          [1.0204],
#          [1.0339],
#          [1.0278],
#          [1.0810],
#          [1.0609],
#          [1.0941],
#          [1.1012],
#          [1.1226],
#          [1.1223],
#          [1.1445],
#          [1.1343],
#          [1.1427],
#          [1.1259],
#          [1.1236],
#          [1.1313],
#          [1.1183],
#          [1.1256],
#          [1.1418],
#          [1.1191],
#          [1.1692],
#          [1.1554],
#          [1.1799],
#          [1.1980],
#          [1.1662],
#          [1.1854],
#          [1.2263],
#          [1.2282],
#          [1.2214],
#          [1.2003],
#          [1.2135],
#          [1.1869],
#          [1.1851],
#          [1.1715],
#          [1.1646],
#          [1.1658],
#          [1.1712],
#          [1.1580],
#          [1.0715],
#          [1.0540],
#          [1.0246],
#          [1.0154],
#          [1.0704],
#          [1.0652],
#          [1.0784],
#          [1.0708],
#          [1.0750],
#          [1.0462],
#          [1.0343],
#          [1.1090],
#          [1.1458],
#          [1.1751],
#          [1.1913],
#          [1.1828],
#          [1.1786],
#          [1.1567],
#          [1.1480],
#          [1.1016],
#          [1.0559],
#          [1.0868],
#          [1.0741],
#          [1.0971],
#          [1.1174],
#          [1.1188],
#          [1.1051],
#          [1.1148],
#          [1.0934],
#          [1.0669],
#          [1.0557],
#          [1.0520],
#          [1.0325],
#          [1.0231],
#          [1.0327],
#          [1.0585],
#          [1.0352],
#          [1.0181],
#          [1.0366],
#          [1.0213],
#          [1.0129],
#          [0.9992],
#          [0.9418],
#          [0.8792],
#          [0.8666],
#          [0.8651],
#          [0.8868],
#          [0.9122],
#          [0.9183],
#          [0.8919],
#          [0.9154],
#          [0.9106],
#          [0.9244],
#          [0.9541],
#          [0.9867],
#          [0.8949],
#          [0.9063],
#          [0.8883],
#          [0.8740],
#          [0.9193],
#          [0.8963],
#          [0.8780],
#          [0.8630],
#          [0.8732],
#          [0.8628],
#          [0.8724],
#          [0.8581],
#          [0.8735],
#          [0.8497],
#          [0.9411],
#          [0.9601],
#          [0.9115],
#          [0.8698],
#          [0.8525],
#          [0.8404],
#          [0.8147],
#          [0.8253],
#          [0.8386],
#          [0.8653],
#          [0.8763],
#          [0.8688],
#          [0.9217],
#          [0.8818],
#          [0.8688],
#          [0.9158],
#          [1.0460],
#          [1.0250],
#          [1.0337],
#          [1.0379],
#          [1.0610],
#          [1.0450],
#          [1.0857],
#          [1.1002],
#          [1.1290],
#          [1.1305],
#          [1.1309],
#          [1.1456],
#          [1.1621],
#          [1.1439],
#          [1.0932],
#          [1.1323],
#          [1.1324],
#          [1.1362],
#          [1.1488],
#          [1.1609],
#          [1.1833],
#          [1.1873],
#          [1.2065],
#          [1.1890],
#          [1.2193],
#          [1.1718],
#          [1.3486],
#          [1.4232],
#          [1.4379],
#          [1.4159],
#          [1.4686],
#          [1.4386],
#          [1.3805],
#          [1.3529],
#          [1.3611],
#          [1.3728],
#          [1.4255],
#          [1.4362],
#          [1.3923],
#          [1.4696],
#          [1.5139],
#          [1.5300],
#          [1.5904],
#          [1.6090],
#          [1.6199],
#          [1.6741],
#          [1.6059],
#          [1.6433],
#          [1.6919],
#          [1.6972],
#          [1.6224],
#          [1.5632],
#          [1.5648],
#          [1.5604],
#          [1.5736],
#          [1.4921],
#          [1.4789],
#          [1.4848],
#          [1.4883],
#          [1.4954],
#          [1.5367],
#          [1.4899],
#          [1.5088],
#          [1.3753],
#          [1.3496],
#          [1.3823],
#          [1.4262],
#          [1.4631],
#          [1.4826],
#          [1.5297],
#          [1.5354],
#          [1.5733],
#          [1.5900],
#          [1.5880],
#          [1.5958],
#          [1.5945],
#          [1.5709],
#          [1.6000],
#          [1.6043],
#          [1.6150],
#          [1.5956],
#          [1.6372],
#          [1.6273],
#          [1.5487],
#          [1.5244],
#          [1.5437],
#          [1.5241],
#          [1.5252],
#          [1.5151],
#          [1.5473],
#          [1.5487],
#          [1.5453],
#          [1.4673],
#          [1.4732],
#          [1.5224],
#          [1.6256],
#          [1.6172],
#          [1.5953],
#          [1.6067],
#          [1.5941],
#          [1.6086],
#          [1.6120],
#          [1.6777],
#          [1.5921],
#          [1.5992],
#          [1.5852],
#          [1.5995],
#          [1.5350],
#          [1.5865],
#          [1.6341],
#          [1.6278],
#          [1.6090],
#          [1.6563],
#          [1.6884],
#          [1.6623],
#          [1.6670],
#          [1.7029],
#          [1.7216],
#          [1.7138],
#          [1.6495],
#          [1.6471],
#          [1.6577],
#          [1.6828],
#          [1.6862],
#          [1.6411],
#          [1.5883],
#          [1.5504],
#          [1.5391],
#          [1.5572],
#          [1.5480],
#          [1.6081],
#          [1.6047],
#          [1.5702],
#          [1.5702],
#          [1.5814],
#          [1.6206],
#          [1.5799],
#          [1.6181],
#          [1.6213],
#          [1.6304],
#          [1.6244],
#          [1.6414],
#          [1.6793],
#          [1.7070],
#          [1.7053],
#          [1.7356],
#          [1.7642],
#          [1.8028],
#          [1.8073],
#          [1.8077],
#          [1.8052],
#          [1.8546],
#          [1.8675],
#          [1.8513],
#          [1.8699],
#          [1.8720],
#          [1.9087],
#          [1.9396],
#          [1.8710],
#          [1.8930],
#          [1.9523],
#          [1.9622],
#          [1.9992],
#          [2.0095],
#          [1.9662],
#          [1.9234],
#          [1.9009]]),
#  array([[164.63122559],
#         [164.92654419],
#         [167.38772583],
#         [161.07733154],
#         [158.87213135],
#         [156.44052124],
#         [154.77680969],
#         [155.5052948 ],
#         [153.38868713],
#         [152.12860107],
#         [153.53636169],
#         [152.05966187],
#         [154.92443848],
#         [160.89028931],
#         [151.44932556],
#         [152.89645386],
#         [150.00213623],
#         [148.35810852],
#         [152.07933044],
#         [154.46176147],
#         [151.3311615 ],
#         [150.3664093 ],
#         [148.09230042],
#         [148.42701721],
#         [149.40164185],
#         [147.51145935],
#         [140.26582336],
#         [136.05233765],
#         [140.23629761],
#         [143.82958984],
#         [144.12490845],
#         [143.16998291],
#         [137.91297913],
#         [138.237854  ],
#         [136.82023621],
#         [136.19018555],
#         [140.76791382],
#         [136.22958374],
#         [140.19694519],
#         [233.46199036],
#         [227.55633545],
#         [222.88349915],
#         [223.01275635],
#         [222.66477966],
#         [223.70870972],
#         [217.27612305],
#         [216.23220825],
#         [216.69947815],
#         [216.97787476],
#         [217.53462219],
#         [220.7956543 ],
#         [217.09716797],
#         [218.58848572],
#         [208.0597229 ],
#         [206.03152466],
#         [208.60655212],
#         [212.07635498],
#         [214.98944092],
#         [216.52229309],
#         [220.24499512],
#         [220.69287109],
#         [223.6789856 ],
#         [225.00283813],
#         [224.84358215],
#         [225.46069336],
#         [225.35121155],
#         [223.48985291],
#         [225.78916931],
#         [226.12757874],
#         [226.97364807],
#         [225.4407959 ],
#         [228.72550964],
#         [227.93916321],
#         [221.73803711],
#         [219.82693481],
#         [221.34985352],
#         [219.79705811],
#         [219.88665771],
#         [219.09034729],
#         [221.62854004],
#         [221.73803711],
#         [221.4692688 ],
#         [215.31790161],
#         [215.78572083],
#         [219.66764832],
#         [227.80976868],
#         [227.1428833 ],
#         [225.42088318],
#         [226.31671143],
#         [225.32133484],
#         [226.46603394],
#         [226.73475647],
#         [231.92062378],
#         [225.16209412],
#         [225.72944641],
#         [224.62458801],
#         [225.74935913],
#         [220.66305542],
#         [224.72413635],
#         [228.47668457],
#         [227.97897339],
#         [226.49589539],
#         [230.22851562],
#         [232.76669312],
#         [230.70629883],
#         [231.0745697 ],
#         [233.91137695],
#         [235.38452148],
#         [234.76739502],
#         [229.69100952],
#         [229.50189209],
#         [230.33799744],
#         [232.31878662],
#         [232.58753967],
#         [229.03407288],
#         [224.86347961],
#         [221.87738037],
#         [220.98153687],
#         [222.41487122],
#         [221.68824768],
#         [226.4262085 ],
#         [226.15716553],
#         [223.43681335],
#         [223.43681335],
#         [224.32366943],
#         [227.41271973],
#         [224.2040863 ],
#         [227.21340942],
#         [227.4724884 ],
#         [228.18994141],
#         [227.7116394 ],
#         [229.05685425],
#         [232.04624939],
#         [234.22850037],
#         [234.09896851],
#         [236.49047852],
#         [238.74247742],
#         [241.79165649],
#         [242.15039062],
#         [242.18026733],
#         [241.98097229],
#         [245.87715149],
#         [246.89355469],
#         [245.61807251],
#         [247.08288574],
#         [247.25227356],
#         [250.15196228],
#         [252.58334351],
#         [247.17256165],
#         [248.90640259],
#         [253.58979797],
#         [254.36703491],
#         [257.28668213],
#         [258.10372925],
#         [254.68588257],
#         [251.30787659],
#         [249.53417969]]))

# %%
with torch.no_grad():
    predicted = model(X_test.to(device)).to('cpu').numpy()
plt.plot(y_test, label = 'Actual Close')
plt.plot(predicted, label = 'Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
predicted
# Out:
# array([[-0.936311  ],
#        [-0.9365391 ],
#        [-0.93573827],
#        ...,
#        [ 0.41238904],
#        [ 0.4038453 ],
#        [ 0.3837119 ]], dtype=float32)

# %%
rmse = np.sqrt(np.mean(predictions - y_test**2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 rmse = np.sqrt(np.mean(predictions - y_test.numpy())**2)
#
# ValueError: operands could not be broadcast together with shapes (1923,1) (503,1)
